# %% [markdown]
# # Case Study 1 : Data Mining in Financial Data

# %% [markdown]
# **Financial Data Collection:**
# * Please collect five-year stock price data of at least 5 stocks. You can choose any stocks you'd like to analyze.
# * You have multiple ways of collecting financial data with Python, here is a reference: https://www.alpharithms.com/python-financial-data-491110/
# * Load the data you collect and start working on your idea.

# %% [markdown]
# # Problem: pick a data science problem that you plan to solve using Stock Price Data
# * The problem should be important and interesting, which has a potential impact in some area.
# * The problem should be solvable using the data available and data science solutions.
#
# Please briefly describe in the following cell: what problem are you trying to solve? why this problem is important and interesting?

# %% [markdown]
# We are going to attempt to create a model that predicts the future stock prices for the google, boeing, netflix, chipotle, and tesla stocks. These models will likely have poor results against future prices but even a small amount of significance would be huge for stock market traders. Any edge in this area would mean a substantial increase in potential money to be earned.

# %% [markdown]
# # Data Collection/Processing:

# %%
#google stock data
import pandas as pd
import matplotlib.pyplot as plt
df_google = pd.read_csv("GOOG.csv")
# Convert 'Date' to datetime format
df_google['Date'] = pd.to_datetime(df_google['Date'])
# Set 'Date' as the index
df_google.set_index('Date', inplace=True)
df_google
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-24   53.824001   53.973751   53.035000   53.695000   53.695000
# 2019-01-25   54.250000   54.700001   54.091000   54.549500   54.549500
# 2019-01-28   54.005501   54.150002   53.189999   53.504002   53.504002
# 2019-01-29   53.633999   53.757500   52.793251   53.030998   53.030998
# 2019-01-30   53.421501   54.549999   53.342499   54.452999   54.452999
# ...                ...         ...         ...         ...         ...
# 2024-01-17  142.910004  143.410004  140.509995  142.889999  142.889999
# 2024-01-18  143.440002  145.585007  143.350006  144.990005  144.990005
# 2024-01-19  146.304993  148.039993  145.800003  147.970001  147.970001
# 2024-01-22  148.710007  150.014999  147.580002  147.710007  147.710007
# 2024-01-23  147.720001  148.860001  147.190002  148.679993  148.679993
#
#               Volume
# Date
# 2019-01-24  27226000
# 2019-01-25  22382000
# 2019-01-28  25686000
# ...

# %%
df_boeing = pd.read_csv("BA.csv")
# Convert 'Date' to datetime format
df_boeing['Date'] = pd.to_datetime(df_boeing['Date'])
# Set 'Date' as the index
df_boeing.set_index('Date', inplace=True)
df_boeing
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-24  358.910004  363.179993  356.899994  358.269989  348.129822
# 2019-01-25  362.489990  366.940002  360.329987  364.200012  353.891998
# 2019-01-28  360.649994  363.170013  357.500000  362.970001  352.696777
# 2019-01-29  363.070007  367.779999  362.410004  364.910004  354.581879
# 2019-01-30  387.399994  391.970001  380.500000  387.720001  376.746307
# ...                ...         ...         ...         ...         ...
# 2024-01-17  202.630005  206.300003  201.649994  203.059998  203.059998
# 2024-01-18  205.639999  213.039993  203.320007  211.610001  211.610001
# 2024-01-19  210.889999  215.160004  209.229996  215.020004  215.020004
# 2024-01-22  213.070007  217.000000  212.360001  214.929993  214.929993
# 2024-01-23  215.350006  216.850006  211.130005  211.500000  211.500000
#
#               Volume
# Date
# 2019-01-24   2801300
# 2019-01-25   3185600
# 2019-01-28   3128900
# ...

# %%
df_netflix = pd.read_csv("NFLX.csv")
df_netflix['Date'] = pd.to_datetime(df_netflix['Date'])
# Set 'Date' as the index
df_netflix.set_index('Date', inplace=True)
df_netflix
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-24  320.600006  331.799988  319.000000  326.670013  326.670013
# 2019-01-25  328.720001  340.000000  328.510010  338.049988  338.049988
# 2019-01-28  334.700012  336.299988  328.880005  335.660004  335.660004
# 2019-01-29  335.869995  338.220001  328.149994  328.899994  328.899994
# 2019-01-30  332.750000  341.779999  330.799988  340.660004  340.660004
# ...                ...         ...         ...         ...         ...
# 2024-01-17  484.500000  486.209991  475.260010  480.329987  480.329987
# 2024-01-18  480.029999  485.769989  478.019989  485.309998  485.309998
# 2024-01-19  484.980011  485.670013  476.059998  482.950012  482.950012
# 2024-01-22  487.549988  489.799988  479.899994  485.709991  485.709991
# 2024-01-23  492.000000  498.959991  481.399994  492.190002  492.190002
#
#               Volume
# Date
# 2019-01-24  11131600
# 2019-01-25  11152900
# 2019-01-28   8652100
# ...

# %%
df_chipotle = pd.read_csv("CMG.csv")
df_chipotle['Date'] = pd.to_datetime(df_chipotle['Date'])
# Set 'Date' as the index
df_chipotle.set_index('Date', inplace=True)
df_chipotle
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-01-24   521.500000   536.049988   518.659973   533.390015   533.390015
# 2019-01-25   539.000000   543.900024   535.349976   543.369995   543.369995
# 2019-01-28   540.599976   542.630005   531.780029   532.000000   532.000000
# 2019-01-29   533.000000   534.000000   519.340027   530.059998   530.059998
# 2019-01-30   534.940002   538.630005   527.030029   532.979980   532.979980
# ...                 ...          ...          ...          ...          ...
# 2024-01-17  2280.909912  2319.429932  2280.909912  2310.439941  2310.439941
# 2024-01-18  2322.000000  2328.699951  2302.679932  2322.820068  2322.820068
# 2024-01-19  2328.000000  2347.300049  2327.000000  2334.600098  2334.600098
# 2024-01-22  2342.000000  2352.760010  2315.959961  2325.000000  2325.000000
# 2024-01-23  2320.000000  2328.320068  2300.610107  2321.820068  2321.820068
#
#             Volume
# Date
# 2019-01-24  783100
# ...

# %%
df_tesla = pd.read_csv("TSLA.csv")
#convert date to a datetime format
df_tesla['Date'] = pd.to_datetime(df_tesla['Date'])
#set date as the index
df_tesla.set_index('Date', inplace=True)
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-24   18.868668   19.578667   18.618668   19.434000   19.434000
# 2019-01-25   19.625999   19.901333   19.303333   19.802668   19.802668
# 2019-01-28   19.527332   19.830667   19.183332   19.758667   19.758667
# 2019-01-29   19.684668   19.903999   19.453333   19.830667   19.830667
# 2019-01-30   20.030001   20.600000   19.899332   20.584667   20.584667
# ...                ...         ...         ...         ...         ...
# 2024-01-17  214.860001  215.669998  212.009995  215.550003  215.550003
# 2024-01-18  216.880005  217.449997  208.740005  211.880005  211.880005
# 2024-01-19  209.990005  213.190002  207.559998  212.190002  212.190002
# 2024-01-22  212.259995  217.800003  206.270004  208.800003  208.800003
# 2024-01-23  211.300003  215.649994  207.750000  209.139999  209.139999
#
#                Volume
# Date
# 2019-01-24  120183000
# 2019-01-25  108744000
# 2019-01-28   96349500
# ...

# %% [markdown]
# # Data Exploration: Exploring the Dataset
#
# **Plot the daily, weekly and monthly returns of a set of stocks of your choice**
# * references:
#     * https://www.investopedia.com/terms/y/yearly-rate-of-return-method.asp
#     * https://www.fool.com/knowledge-center/how-to-calculate-a-monthly-return-on-investment/#:~:text=Take%20the%20ending%20balance%2C%20and,corresponds%20to%20your%20monthly%20return.
#     * https://www.investopedia.com/terms/i/intraday-return.asp#:~:text=How%20Is%20Daily%20Return%20Calculated,price%2C%20then%20multiply%20by%20100.

# %%
#daily returns
df_tesla['daily_return'] = (df_tesla['Adj Close'] / df_tesla['Adj Close'].shift(1)) - 1

#calculate weekly returns
df_tesla['weekly_return'] = (df_tesla['Adj Close'].resample('W-Fri').last() / df_tesla['Adj Close'].resample('W-Fri').first()) - 1

#calculate monthly returns
df_tesla['monthly_return'] = (df_tesla['Adj Close'].resample('M').last() / df_tesla['Adj Close'].resample('M').first()) - 1

plt.figure(figsize=(12, 8))
#plot daily returns
plt.subplot(3, 1, 1)
plt.plot(df_tesla.index, df_tesla['daily_return'], marker='o')
plt.title('Daily Returns')

#plot weekly returns
plt.subplot(3, 1, 2)
plt.plot(df_tesla.index, df_tesla['weekly_return'], marker='o')
plt.title('Weekly Returns')

#plot monthly returns
plt.subplot(3, 1, 3)
plt.plot(df_tesla.index, df_tesla['monthly_return'], marker='o')
plt.title('Monthly Returns')

plt.show()

# %%
#daily returns
df_google['daily_return'] = (df_google['Adj Close'] / df_google['Adj Close'].shift(1)) - 1

#calculate weekly returns
df_google['weekly_return'] = (df_google['Adj Close'].resample('W-Fri').last() / df_google['Adj Close'].resample('W-Fri').first()) - 1

#calculate monthly returns
df_google['monthly_return'] = (df_google['Adj Close'].resample('M').last() / df_google['Adj Close'].resample('M').first()) - 1

plt.figure(figsize=(12, 8))
#plot daily returns
plt.subplot(3, 1, 1)
plt.plot(df_google.index, df_google['daily_return'], marker='o')
plt.title('Google - Daily Returns')

#plot weekly returns
plt.subplot(3, 1, 2)
plt.plot(df_google.index, df_google['weekly_return'], marker='o')
plt.title('Google - Weekly Returns')

#plot monthly returns
plt.subplot(3, 1, 3)
plt.plot(df_google.index, df_google['monthly_return'], marker='o')
plt.title('Google - Monthly Returns')

plt.show()

# %%
#daily returns
df_boeing['daily_return'] = (df_boeing['Adj Close'] / df_boeing['Adj Close'].shift(1)) - 1

#calculate weekly returns
df_boeing['weekly_return'] = (df_boeing['Adj Close'].resample('W-Fri').last() / df_boeing['Adj Close'].resample('W-Fri').first()) - 1

#calculate monthly returns
df_boeing['monthly_return'] = (df_boeing['Adj Close'].resample('M').last() / df_boeing['Adj Close'].resample('M').first()) - 1

plt.figure(figsize=(12, 8))
#plot daily returns
plt.subplot(3, 1, 1)
plt.plot(df_boeing.index, df_boeing['daily_return'], marker='o')
plt.title('Boeing - Daily Returns')

#plot weekly returns
plt.subplot(3, 1, 2)
plt.plot(df_boeing.index, df_boeing['weekly_return'], marker='o')
plt.title('Boeing - Weekly Returns')

#plot monthly returns
plt.subplot(3, 1, 3)
plt.plot(df_boeing.index, df_boeing['monthly_return'], marker='o')
plt.title('Boeing - Monthly Returns')

plt.show()

# %%
#daily returns
df_netflix['daily_return'] = (df_netflix['Adj Close'] / df_netflix['Adj Close'].shift(1)) - 1

#calculate weekly returns
df_netflix['weekly_return'] = (df_netflix['Adj Close'].resample('W-Fri').last() / df_netflix['Adj Close'].resample('W-Fri').first()) - 1

#calculate monthly returns
df_netflix['monthly_return'] = (df_netflix['Adj Close'].resample('M').last() / df_netflix['Adj Close'].resample('M').first()) - 1

plt.figure(figsize=(12, 8))
#plot daily returns
plt.subplot(3, 1, 1)
plt.plot(df_netflix.index, df_netflix['daily_return'], marker='o')
plt.title('Netflix - Daily Returns')

#plot weekly returns
plt.subplot(3, 1, 2)
plt.plot(df_netflix.index, df_netflix['weekly_return'], marker='o')
plt.title('Netflix - Weekly Returns')

#plot monthly returns
plt.subplot(3, 1, 3)
plt.plot(df_netflix.index, df_netflix['monthly_return'], marker='o')
plt.title('Netflix - Monthly Returns')

plt.show()

# %%
import matplotlib.pyplot as plt

#daily returns
df_chipotle['daily_return'] = (df_chipotle['Adj Close'] / df_chipotle['Adj Close'].shift(1)) - 1

#calculate weekly returns
df_chipotle['weekly_return'] = (df_chipotle['Adj Close'].resample('W-Fri').last() / df_chipotle['Adj Close'].resample('W-Fri').first()) - 1

#calculate monthly returns
df_chipotle['monthly_return'] = (df_chipotle['Adj Close'].resample('M').last() / df_chipotle['Adj Close'].resample('M').first()) - 1

plt.figure(figsize=(12, 8))
#plot daily returns
plt.subplot(3, 1, 1)
plt.plot(df_chipotle.index, df_chipotle['daily_return'], marker='o')
plt.title('Chipotle - Daily Returns')

#plot weekly returns
plt.subplot(3, 1, 2)
plt.plot(df_chipotle.index, df_chipotle['weekly_return'], marker='o')
plt.title('Chipotle - Weekly Returns')

#plot monthly returns
plt.subplot(3, 1, 3)
plt.plot(df_chipotle.index, df_chipotle['monthly_return'], marker='o')
plt.title('Chipotle - Monthly Returns')

plt.show()

# %% [markdown]
# **Other data explorations you would like to present:**

# %%
#create histogram for adj close
plt.figure(figsize=(12, 6))
plt.hist(df_google['Adj Close'], bins=25, color='blue')
plt.xlabel('Adj Close')
plt.ylabel('Frequency')
plt.title('Histogram of Adj Close for Google')
plt.grid(axis='y')
plt.show()

# %%
#create histogram for adj close
plt.figure(figsize=(12, 6))
plt.hist(df_boeing['Adj Close'], bins=25, color='blue')
plt.xlabel('Adj Close')
plt.ylabel('Frequency')
plt.title('Histogram of Adj Close for Boeing')
plt.grid(axis='y')
plt.show()

# %%
#create histogram for adj close
plt.figure(figsize=(12, 6))
plt.hist(df_netflix['Adj Close'], bins=25, color='blue')
plt.xlabel('Adj Close')
plt.ylabel('Frequency')
plt.title('Histogram of Adj Close for Netflix')
plt.grid(axis='y')
plt.show()

# %%
#create histogram for adj close
plt.figure(figsize=(12, 6))
plt.hist(df_chipotle['Adj Close'], bins=25, color='blue')
plt.xlabel('Adj Close')
plt.ylabel('Frequency')
plt.title('Histogram of Adj Close for Chipotle')
plt.grid(axis='y')
plt.show()

# %%
#create histogram for adj close
plt.figure(figsize=(12, 6))
plt.hist(df_tesla['Adj Close'], bins=25, color='blue')
plt.xlabel('Adj Close')
plt.ylabel('Frequency')
plt.title('Histogram of Adj Close for Tesla')
plt.grid(axis='y')
plt.show()

# %%
#create a new dataframe for each of the stocks
df_google2 =pd.read_csv("GOOG.csv")
df_google2['Date'] = pd.to_datetime(df_google2['Date'])

df_boeing2 = pd.read_csv("BA.csv")
df_boeing2['Date'] = pd.to_datetime(df_boeing2['Date'])

df_chipotle2 = pd.read_csv("CMG.csv")
df_chipotle2['Date'] = pd.to_datetime(df_chipotle2['Date'])

df_tesla2 = pd.read_csv("TSLA.csv")
df_tesla2['Date'] = pd.to_datetime(df_tesla2['Date'])

df_netflix2 = pd.read_csv("NFLX.csv")
df_netflix2['Date'] = pd.to_datetime(df_netflix2['Date'])

# %% [markdown]
# # The Solution: implement a data science solution to the problem you are trying to solve.

# %% [markdown]
# **Briefly describe the idea of your solutions to the problem in the following cell (you should use at least 2 methods/models to solve the problem, and compare the performance. You are free to use any machine learning model or statistical model like ARIMA.):**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

df_google2['Date'] = pd.to_datetime(df_google2['Date'])
df_google2 = df_google2.sort_values(by='Date')
train_percentage = 0.8
split_index = int(len(df_google2) * train_percentage)
train_data = df_google2.iloc[:split_index]
test_data = df_google2.iloc[split_index:]

X_train = np.array(train_data['Date']).astype(np.int64).reshape(-1, 1)
y_train = train_data['Adj Close']

X_test = np.array(test_data['Date']).astype(np.int64).reshape(-1, 1)
y_test = test_data['Adj Close']

#create a linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)

#calculate mse of this model
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error on Testing Set:", mse)
slope = model.coef_[0]
print("Slope:", slope)
#plot the model
plt.figure(figsize=(12, 6))
plt.scatter(df_google2['Date'], df_google2['Adj Close'], label='Adj Close', color='red', s=10)
plt.plot(test_data['Date'], predictions, label='Linear Regression Model', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Linear Regression Model')
plt.legend()
plt.show()
# Out:
# Mean Squared Error on Testing Set: 621.0337788421947
# Slope: 6.459624126710191e-16

# %% [markdown]
# I am going to create a linear model for each stock using its historical data. This model is relatively simple and likely will not perform well due to the volatility of the stocks but it will give a rough estimate of the direction which the stock will head in. The other model will be an ETS model which has a higher degree of complexity which will be able to capture more of the intricate aspects of the data. It will likely be more accurate as it takes error, trend, and seasonality into account.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error

df_google2['Date'] = pd.to_datetime(df_google2['Date'])
df_google2 = df_google2.sort_values(by='Date')

#training and testing sets
train_percentage = 0.8
split_index = int(len(df_google2) * train_percentage)
train_data = df_google2.iloc[:split_index]
test_data = df_google2.iloc[split_index:]

# ETS model
model = ExponentialSmoothing(train_data['Adj Close'], trend='add', seasonal='multiplicative', seasonal_periods=12)
fit_model = model.fit()

# predictions
predictions = fit_model.forecast(len(test_data))

# MSE
mse = mean_squared_error(test_data['Adj Close'], predictions)
print("Mean Squared Error on Testing Set:", mse)

# plot the results
plt.figure(figsize=(12, 6))
plt.scatter(df_google2['Date'], df_google2['Adj Close'], label='Actual Adj Close', color='red', s=10)
plt.plot(test_data['Date'], predictions, label='ETS Model', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Google Linear Model')
plt.legend()
plt.show()
# Out:
# Mean Squared Error on Testing Set: 493.2914943929921

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error

#convert to datetime
df_google2['Date'] = pd.to_datetime(df_google2['Date'])
df_google2 = df_google2.sort_values(by='Date')

# fit the ETS model using the entire dataset
model = ExponentialSmoothing(df_google2['Adj Close'], trend='add', seasonal='multiplicative', seasonal_periods=12)
fit_model = model.fit()

# forecast the next year
future_dates = pd.date_range(start=df_google2['Date'].max() + pd.DateOffset(1), periods=12, freq='MS')
predictions_future = fit_model.forecast(len(future_dates))

# plot the forecast
plt.figure(figsize=(12, 6))
plt.scatter(df_google2['Date'], df_google2['Adj Close'], label='Actual Adj Close', color='red', s=10)
plt.plot(future_dates, predictions_future, label='Forecast for the Next Year', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Google ETS Model')
plt.legend()
plt.show()

# %%
df_boeing2['Date'] = pd.to_datetime(df_boeing2['Date'])
df_boeing2 = df_boeing2.sort_values(by='Date')

#training and testing sets
train_percentage = 0.8
split_index = int(len(df_boeing2) * train_percentage)
train_data = df_boeing2.iloc[:split_index]
test_data = df_boeing2.iloc[split_index:]

X_train = np.array(train_data['Date']).astype(np.int64).reshape(-1, 1)
y_train = train_data['Adj Close']

X_test = np.array(test_data['Date']).astype(np.int64).reshape(-1, 1)
y_test = test_data['Adj Close']

# linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)

# MSE
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error on Testing Set:", mse)

# slope
slope = model.coef_[0]
print("Slope:", slope)

# Plot the model
plt.figure(figsize=(12, 6))
plt.scatter(df_boeing2['Date'], df_boeing2['Adj Close'], label='Actual Adj Close', color='red', s=10)
plt.plot(test_data['Date'], predictions, label='Linear Regression Model', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Linear Regression Model - Boeing Stock')
plt.legend()
plt.show()
# Out:
# Mean Squared Error on Testing Set: 12942.458138010361
# Slope: -1.6774586141133747e-15

# %%
df_boeing2['Date'] = pd.to_datetime(df_boeing2['Date'])
df_boeing2 = df_boeing2.sort_values(by='Date')

#training and testing sets
train_percentage = 0.8
split_index = int(len(df_boeing2) * train_percentage)
train_data = df_boeing2.iloc[:split_index]
test_data = df_boeing2.iloc[split_index:]

# ETS model
model = ExponentialSmoothing(train_data['Adj Close'], trend='add', seasonal='multiplicative', seasonal_periods=12)
fit_model = model.fit()

# predictions
predictions = fit_model.forecast(len(test_data))

# MSE
mse = mean_squared_error(test_data['Adj Close'], predictions)
print("Mean Squared Error on Testing Set:", mse)

# plot the model
plt.figure(figsize=(12, 6))
plt.scatter(df_boeing2['Date'], df_boeing2['Adj Close'], label='Actual Adj Close', color='red', s=10)
plt.plot(test_data['Date'], predictions, label='ETS Model', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('ETS Model vs. Actual Adj Close - Boeing Stock')
plt.legend()
plt.show()
# Out:
# Mean Squared Error on Testing Set: 1164.2551698247062

# %%
df_boeing2['Date'] = pd.to_datetime(df_boeing2['Date'])
df_boeing2 = df_boeing2.sort_values(by='Date')

# ETS model
model = ExponentialSmoothing(df_boeing2['Adj Close'], trend='add', seasonal='multiplicative', seasonal_periods=12)
fit_model = model.fit()

# forecast the next year
future_dates = pd.date_range(start=df_boeing2['Date'].max() + pd.DateOffset(1), periods=12, freq='MS')
predictions_future = fit_model.forecast(len(future_dates))

# Plot the forecast
plt.figure(figsize=(12, 6))
plt.scatter(df_boeing2['Date'], df_boeing2['Adj Close'], label='Actual Adj Close', color='red', s=10)
plt.plot(future_dates, predictions_future, label='Forecast for the Next Year', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('ETS Model with Forecast for the Next Year - Boeing Stock')
plt.legend()
plt.show()

# %%
df_netflix2['Date'] = pd.to_datetime(df_netflix2['Date'])
df_netflix2 = df_netflix2.sort_values(by='Date')

# training and testing sets
train_percentage = 0.8
split_index = int(len(df_netflix2) * train_percentage)
train_data = df_netflix2.iloc[:split_index]
test_data = df_netflix2.iloc[split_index:]

X_train = np.array(train_data['Date']).astype(np.int64).reshape(-1, 1)
y_train = train_data['Adj Close']

X_test = np.array(test_data['Date']).astype(np.int64).reshape(-1, 1)
y_test = test_data['Adj Close']

# linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)

# MSE
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error on Testing Set:", mse)

# get the slope
slope = model.coef_[0]
print("Slope:", slope)

# plot the model
plt.figure(figsize=(12, 6))
plt.scatter(df_netflix2['Date'], df_netflix2['Adj Close'], label='Actual Adj Close', color='red', s=10)
plt.plot(test_data['Date'], predictions, label='Linear Regression Model', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Linear Regression Model - Netflix Stock')
plt.legend()
plt.show()
# Out:
# Mean Squared Error on Testing Set: 3249.8717403146916
# Slope: -1.1686190307937647e-16

# %%
df_netflix2['Date'] = pd.to_datetime(df_netflix2['Date'])
df_netflix2 = df_netflix2.sort_values(by='Date')

# training and testing sets
train_percentage = 0.8
split_index = int(len(df_netflix2) * train_percentage)
train_data = df_netflix2.iloc[:split_index]
test_data = df_netflix2.iloc[split_index:]

# ETS model
model = ExponentialSmoothing(train_data['Adj Close'], trend='add', seasonal='add', seasonal_periods=12)
fit_model = model.fit()

# make predictions
predictions = fit_model.forecast(len(test_data))

# MSE
mse = mean_squared_error(test_data['Adj Close'], predictions)
print("Mean Squared Error on Testing Set:", mse)

# plot the model
plt.figure(figsize=(12, 6))
plt.scatter(df_netflix2['Date'], df_netflix2['Adj Close'], label='Actual Adj Close', color='red', s=10)
plt.plot(test_data['Date'], predictions, label='ETS Model', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('ETS Model vs. Actual Adj Close - Netflix Stock')
plt.legend()
plt.show()
# Out:
# Mean Squared Error on Testing Set: 6476.199511694071

# %%
df_netflix2['Date'] = pd.to_datetime(df_netflix2['Date'])
df_netflix2 = df_netflix2.sort_values(by='Date')

# ETS model
model = ExponentialSmoothing(df_netflix2['Adj Close'], trend='add', seasonal='multiplicative', seasonal_periods=12)
fit_model = model.fit()

# forecast the next year
future_dates = pd.date_range(start=df_netflix2['Date'].max() + pd.DateOffset(1), periods=12, freq='MS')
predictions_future = fit_model.forecast(len(future_dates))

# plot the forecast
plt.figure(figsize=(12, 6))
plt.scatter(df_netflix2['Date'], df_netflix2['Adj Close'], label='Actual Adj Close', color='red', s=10)
plt.plot(future_dates, predictions_future, label='Forecast for the Next Year', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('ETS Model with Forecast for the Next Year - Netflix Stock')
plt.legend()
plt.show()

# %%
df_chipotle2['Date'] = pd.to_datetime(df_chipotle2['Date'])
df_chipotle2 = df_chipotle2.sort_values(by='Date')

# training and testing sets
train_percentage = 0.8
split_index = int(len(df_chipotle2) * train_percentage)
train_data = df_chipotle2.iloc[:split_index]
test_data = df_chipotle2.iloc[split_index:]

#  linear regression
X_train = np.array(train_data['Date']).astype(np.int64).reshape(-1, 1)
y_train = train_data['Adj Close']

X_test = np.array(test_data['Date']).astype(np.int64).reshape(-1, 1)
y_test = test_data['Adj Close']

model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)

# MSE
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error on Testing Set:", mse)

# get the slope
slope = model.coef_[0]
print("Slope:", slope)

# plot the linear regression model
plt.figure(figsize=(12, 6))
plt.scatter(df_chipotle2['Date'], df_chipotle2['Adj Close'], label='Actual Adj Close', color='red', s=10)
plt.plot(test_data['Date'], predictions, label='Linear Regression Model', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Linear Regression Model - Chipotle Stock')
plt.legend()
plt.show()
# Out:
# Mean Squared Error on Testing Set: 30286.310673791744
# Slope: 8.91996545360734e-15

# %%
df_chipotle2['Date'] = pd.to_datetime(df_chipotle2['Date'])
df_chipotle2 = df_chipotle2.sort_values(by='Date')

# training and testing sets
train_percentage = 0.8
split_index = int(len(df_chipotle2) * train_percentage)
train_data = df_chipotle2.iloc[:split_index]
test_data = df_chipotle2.iloc[split_index:]

# ETS model
model = ExponentialSmoothing(train_data['Adj Close'], trend='add', seasonal='add', seasonal_periods=12)
fit_model = model.fit()

predictions = fit_model.forecast(len(test_data))

# MSE
mse = mean_squared_error(test_data['Adj Close'], predictions)
print("Mean Squared Error on Testing Set:", mse)

# plot the model
plt.figure(figsize=(12, 6))
plt.scatter(df_chipotle2['Date'], df_chipotle2['Adj Close'], label='Actual Adj Close', color='red', s=10)
plt.plot(test_data['Date'], predictions, label='ETS Model', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('ETS Model vs. Actual Adj Close - Chipotle Stock')
plt.legend()
plt.show()
# Out:
# Mean Squared Error on Testing Set: 24710.04906838959

# %%
df_chipotle2['Date'] = pd.to_datetime(df_chipotle2['Date'])
df_chipotle2 = df_chipotle2.sort_values(by='Date')

# ETS model
model = ExponentialSmoothing(df_chipotle2['Adj Close'], trend='add', seasonal='multiplicative', seasonal_periods=12)
fit_model = model.fit()

# forecast the next year
future_dates = pd.date_range(start=df_chipotle2['Date'].max() + pd.DateOffset(1), periods=12, freq='MS')
predictions_future = fit_model.forecast(len(future_dates))

# plot the forecast
plt.figure(figsize=(12, 6))
plt.scatter(df_chipotle2['Date'], df_chipotle2['Adj Close'], label='Actual Adj Close', color='red', s=10)
plt.plot(future_dates, predictions_future, label='Forecast for the Next Year', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('ETS Model with Forecast for the Next Year - Chipotle Stock')
plt.legend()
plt.show()

# %%
df_tesla2['Date'] = pd.to_datetime(df_tesla2['Date'])
df_tesla2 = df_tesla2.sort_values(by='Date')

# training and testing sets
train_percentage = 0.8
split_index = int(len(df_tesla2) * train_percentage)
train_data = df_tesla2.iloc[:split_index]
test_data = df_tesla2.iloc[split_index:]

X_train = np.array(train_data['Date']).astype(np.int64).reshape(-1, 1)
y_train = train_data['Adj Close']

X_test = np.array(test_data['Date']).astype(np.int64).reshape(-1, 1)
y_test = test_data['Adj Close']

# linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)

# MSE
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error on Testing Set:", mse)

# slope
slope = model.coef_[0]
print("Slope:", slope)

# plot the linear regression model
plt.figure(figsize=(12, 6))
plt.scatter(df_tesla2['Date'], df_tesla2['Adj Close'], label='Actual Adj Close', color='red', s=10)
plt.plot(test_data['Date'], predictions, label='Linear Regression Model', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Linear Regression Model - Tesla Stock')
plt.legend()
plt.show()
# Out:
# Mean Squared Error on Testing Set: 22008.8131681792
# Slope: 2.6323052379893253e-15

# %%
df_tesla2['Date'] = pd.to_datetime(df_tesla2['Date'])
df_tesla2 = df_tesla2.sort_values(by='Date')

# training and testing sets
train_percentage = 0.8
split_index = int(len(df_tesla2) * train_percentage)
train_data = df_tesla2.iloc[:split_index]
test_data = df_tesla2.iloc[split_index:]

# ETS model
model = ExponentialSmoothing(train_data['Adj Close'], trend='add', seasonal='add', seasonal_periods=12)
fit_model = model.fit()

# predictions
predictions = fit_model.forecast(len(test_data))

# MSE
mse = mean_squared_error(test_data['Adj Close'], predictions)
print("Mean Squared Error on Testing Set:", mse)

# plot the results
plt.figure(figsize=(12, 6))
plt.scatter(df_tesla2['Date'], df_tesla2['Adj Close'], label='Actual Adj Close', color='red', s=10)
plt.plot(test_data['Date'], predictions, label='ETS Model', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('ETS Model vs. Actual Adj Close - Tesla Stock')
plt.legend()
plt.show()
# Out:
# Mean Squared Error on Testing Set: 7421.339813266595

# %%
df_tesla2['Date'] = pd.to_datetime(df_tesla2['Date'])
df_tesla2 = df_tesla2.sort_values(by='Date')

# ETS model
model = ExponentialSmoothing(df_tesla2['Adj Close'], trend='add', seasonal='add', seasonal_periods=12)
fit_model = model.fit()

# forecast the next year
future_dates = pd.date_range(start=df_tesla2['Date'].max() + pd.DateOffset(1), periods=12, freq='MS')
predictions_future = fit_model.forecast(len(future_dates))

# plot the forecast
plt.figure(figsize=(12, 6))
plt.scatter(df_tesla2['Date'], df_tesla2['Adj Close'], label='Actual Adj Close', color='red', s=10)
plt.plot(future_dates, predictions_future, label='Forecast for the Next Year', color='blue')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('ETS Model with Forecast for the Next Year - Tesla Stock')
plt.legend()
plt.show()

# %% [markdown]
# **Write codes to implement the solution in python:**

# %% [markdown]
# # Results: summarize and visualize the results discovered from the analysis
#
# **Summarize the results of different models. Compare the perfomance and explain it. Please use figures or tables to present the results.**

# %%
#create a dictionary that has the MSE's from each model
mse_values = {
    'Tesla_ETS': 7421.339813266595,
    'Tesla_Linear': 22008.8131681792,
    'Chipotle_ETS': 24710.04906838959,
    'Chipotle_Linear': 30286.310673791744,
    'Netflix_ETS': 6476.199511694071,
    'Netflix_Linear': 3249.8717403146916,
    'Boeing_ETS': 1164.2551698247062,
    'Boeing_Linear': 12942.458138010361,
    'Google_ETS': 493.2914943929921,
    'Google_Linear': 621.033778842194,
}

# make a DataFrame
mse_df = pd.DataFrame(list(mse_values.items()), columns=['Model', 'MSE'])


mse_df
# Out:
#              Model           MSE
# 0        Tesla_ETS   7421.339813
# 1     Tesla_Linear  22008.813168
# 2     Chipotle_ETS  24710.049068
# 3  Chipotle_Linear  30286.310674
# 4      Netflix_ETS   6476.199512
# 5   Netflix_Linear   3249.871740
# 6       Boeing_ETS   1164.255170
# 7    Boeing_Linear  12942.458138
# 8       Google_ETS    493.291494
# 9    Google_Linear    621.033779

# %% [markdown]
# It can be seen that the ETS model performed better against the test set for every stock except for netflix. The more complex model takes in more factors which allows it to produce a better result. The increase in flexibility if oftentimes not worth the improved MSE but it seems that for most of these models, the improvement is significant enough to prove that it is worth it. Netflix is interesting because the linear model performed surprisingly well on the test set and this can be seen visually as well. We would have to change the data used for training and testing to see if this was a fluke or if it really performs well for this stock.

# %%
# bar graph
plt.figure(figsize=(12, 6))
plt.bar(mse_df['Model'], mse_df['MSE'], color='blue')
plt.xlabel('Model')
plt.ylabel('MSE')
plt.title('MSE Comparison')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels slightly
plt.show()

# %% [markdown]
# The magnitudes of each MSE is vastly different which shows how certain stocks might be more predictable than others. Despite this oberservation, I still believe that all the models performed pretty poorly and that stock price is just very difficult to predict. Each models only use would likely be to give a rough estimate of whether a stock is going to be performing well or poorly in the future.

# %% [markdown]
# # Done
#
# All set!
#
# **What do you need to submit?**
#
# * **Notebook File**: Save this Jupyter notebook, and submit it in BrightSpace. This is the file you need to submit. Please make sure all the plotted tables and figures are in the notebook.
#
#
# **How to submit:**
# * Please submit through BrightSpace, in the Assignment "Case Study 1".
